# %% [markdown]
# The purpose of this analysis is to understand how my listening behavior influences my activity levels, and ultimately attempting to create playlists that motivate me to exercise more

# %%
# Importing packages 

# Importing relevant packages
import pandas as pd
from sklearn.cluster import KMeans


import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np

from pathlib import Path

import calendar
import datetime

import xml.etree.ElementTree
import io
import seaborn as sb

# %%
# Importing data that I want to consider in my analysis
## my listening history: Last.fm
listening = pd.read_csv('/Users/juliacreighton/Downloads/juliacreighton (4).csv',header=None)
listening.columns = ['Artist_Name','Album','Song','Date']

# %%
## my step counts: Apple
path = '/Users/juliacreighton/Downloads/apple_health_export/export.xml'
def iter_records(healthdata):
    healthdata_attr = healthdata.attrib
    for rec in healthdata.iterfind('.//Record'):
        rec_dict = healthdata_attr.copy()
        rec_dict.update(healthdata.attrib)
        for k, v in rec.attrib.items():
            if 'date' in k.lower():
                rec_dict[k] = datetime.datetime.strptime(v, '%Y-%m-%d %H:%M:%S %z')
            else:
                rec_dict[k] = v
        yield rec_dict
e = xml.etree.ElementTree.parse(path).getroot()
health_data = pd.DataFrame(list(iter_records(e)))

# %%
# examining datatypes
print(health_data.dtypes)
print('****')
print(listening.dtypes)
# Out:
# creationDate     datetime64[ns, UTC-07:00]
# device                              object
# endDate          datetime64[ns, UTC-07:00]
# locale                              object
# sourceName                          object
# sourceVersion                       object
# startDate        datetime64[ns, UTC-07:00]
# type                                object
# unit                                object
# value                               object
# dtype: object
# ****
# Artist_Name    object
# Album          object
# Song           object
# dtype: object

# %%
# The health data is stored with date time objects, but the listening data isn't I'll change the formatting.
listening['Date'] = pd.to_datetime(listening.Date)
listening.set_index('Date',inplace=True)
listening.index = listening.index.tz_localize('UTC').tz_convert('US/Pacific')

# %%
listening.index = listening.index.round('H')

# %%
listening.tail()
# Out:
#                              Artist_Name                 Album  \
# Date
# 2016-06-09 15:00:00-07:00      Izzy Bizu  Adam & Eve (Remixes)
# 2016-06-09 15:00:00-07:00     A$AP Rocky     At.Long.Last.A$AP
# 2016-06-09 15:00:00-07:00            Omi           Cheerleader
# 2016-06-09 15:00:00-07:00  Glass Animals         ZABA (Deluxe)
# 2016-06-09 15:00:00-07:00      Blackbear             deadroses
#
#                                                                  Song
# Date
# 2016-06-09 15:00:00-07:00                  Adam & Eve - Swindle Remix
# 2016-06-09 15:00:00-07:00                                    Everyday
# 2016-06-09 15:00:00-07:00  Cheerleader - Felix Jaehn Remix Radio Edit
# 2016-06-09 15:00:00-07:00                                       Hazey
# 2016-06-09 15:00:00-07:00                                       90210

# %%
health_data.dtypes
# Out:
# creationDate      datetime64[ns, UTC-07:00]
# device                               object
# endDate           datetime64[ns, UTC-07:00]
# locale                               object
# sourceName                           object
# sourceVersion                        object
# startDate        datetime64[ns, US/Pacific]
# type                                 object
# unit                                 object
# value                                object
# Start_Hour                            int64
# dtype: object

# %%
health_data['startDate'] = pd.to_datetime(health_data['startDate'])

# %%
health_data['startDate'] = pd.DatetimeIndex(health_data['startDate']).tz_convert('US/Pacific')

# %%
health_data['Start_Hour']= health_data['startDate'].dt.hour

# %%
#health_data.index = pd.DatetimeIndex(health_data['startDate']).tz_convert(None)

# %%
#health_data.index.tz_localize(tz='US/Pacific')

# %%
#health_data.index.tz_localize('US/Pacific')#.round('H') #.tz_localize('US/Pacific',ambiguous=False)

# %%
#health_data.set_index(['startDate'],inplace=True)

# %%
#health_data.index = health_data.index.tz_convert('US/Pacific')

# %%
#health_data.index = pd.to_datetime(health_data.index)

# %%
#listening.index = 
#health_data.index.round('H')

# %%
step_data = health_data[health_data.type=='HKQuantityTypeIdentifierStepCount']

# %%
step_data['value'].fillna(0,inplace=True)
step_data['value'] = step_data['value'].astype('int')
# Out:
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py:5430: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
step_data['Date'] = step_data['startDate'].dt.date
# Out:
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
step_data.head()
# Out:
#                creationDate device                   endDate locale  \
# 1 2014-09-17 17:22:41-07:00    NaN 2014-09-10 16:24:13-07:00  en_US
# 2 2014-09-17 17:22:41-07:00    NaN 2014-09-10 17:31:14-07:00  en_US
# 3 2014-09-17 17:22:41-07:00    NaN 2014-09-10 17:36:35-07:00  en_US
# 4 2014-09-17 17:22:41-07:00    NaN 2014-09-10 17:41:40-07:00  en_US
# 5 2014-09-17 17:22:41-07:00    NaN 2014-09-10 17:47:40-07:00  en_US
#
#   sourceName sourceVersion                 startDate  \
# 1     Health           NaN 2014-09-10 16:24:08-07:00
# 2     Health           NaN 2014-09-10 17:31:09-07:00
# 3     Health           NaN 2014-09-10 17:36:30-07:00
# 4     Health           NaN 2014-09-10 17:41:35-07:00
# 5     Health           NaN 2014-09-10 17:47:35-07:00
#
#                                 type   unit  value  Start_Hour        Date
# 1  HKQuantityTypeIdentifierStepCount  count     10          16  2014-09-10
# 2  HKQuantityTypeIdentifierStepCount  count     14          17  2014-09-10
# 3  HKQuantityTypeIdentifierStepCount  count    396          17  2014-09-10
# 4  HKQuantityTypeIdentifierStepCount  count    266          17  2014-09-10
# 5  HKQuantityTypeIdentifierStepCount  count    291          17  2014-09-10

# %%
#step_data.reset_index(inplace=True)
hourly_step_data = step_data.groupby(['Date','Start_Hour'], as_index=False)['value'].sum()

# %%
hourly_step_data.rename({'value':'Steps'},axis=1,inplace=True)

# %%
#hourly_step_data.set_index(['startDate'],inplace=True)

# %%
hourly_step_data.head()
# Out:
#          Date  Start_Hour  Steps
# 0  2014-09-10          16     10
# 1  2014-09-10          17   1406
# 2  2014-09-10          18    122
# 3  2014-09-10          19     10
# 4  2014-09-10          20     19

# %%
listening['Hour'] = listening.index.hour
listening['Listen_Date'] =listening.index.date

# %%
hourly_listening_count = listening.reset_index().groupby(['Listen_Date','Hour'], as_index=False)['Song'].count()

# %%
hourly_step_data['Date'] = pd.to_datetime(hourly_step_data['Date'])

# %%
hourly_listening_count['Listen_Date'] = pd.to_datetime(hourly_listening_count['Listen_Date'])

# %%
listening_steps_hourly = hourly_listening_count.merge(hourly_step_data, left_on=['Listen_Date','Hour'], right_on =['Date','Start_Hour'],how ='outer')

# %%
listening_steps_hourly.tail()
# Out:
#       Listen_Date  Hour  Song       Date  Start_Hour  Steps
# 15063         NaT   NaN   NaN 2018-06-09        22.0  168.0
# 15064         NaT   NaN   NaN 2018-06-10         8.0  396.0
# 15065         NaT   NaN   NaN 2018-06-10         9.0  438.0
# 15066         NaT   NaN   NaN 2018-06-10        11.0   16.0
# 15067         NaT   NaN   NaN 2018-06-10        15.0  157.0

# %%
listening_steps_hourly.Date = listening_steps_hourly.Date.combine_first(listening_steps_hourly['Listen_Date'])
listening_steps_hourly.Hour = listening_steps_hourly.Hour.combine_first(listening_steps_hourly['Start_Hour'])

# %%
listening_steps_hourly['Steps_Missing'] = pd.isna(listening_steps_hourly['Steps'])
listening_steps_hourly['Listening_Missing'] = pd.isna(listening_steps_hourly['Song'])

# %%
listening_steps_hourly.drop(['Listen_Date','Start_Hour'],axis=1,inplace=True)

# %%
listening_steps_hourly.set_index('Date',inplace=True)

# %%
listening_steps_hourly.fillna(0).plot(secondary_y='Song',figsize=(20,8))

# %%
#.loc['2018-5-01':'2018-6-10']
listening_steps_hourly.fillna(0).groupby(listening_steps_hourly.index).sum().plot(secondary_y='Song',figsize=(20,8))

# %%
# Out:
# Index([2016-06-09, 2016-06-09, 2016-06-09, 2016-06-09, 2016-06-09, 2016-06-09,
#        2016-06-09, 2016-06-10, 2016-06-10, 2016-06-10,
#        ...
#        2018-06-09, 2018-06-09, 2018-06-09, 2018-06-09, 2018-06-09, 2018-06-09,
#        2018-06-10, 2018-06-10, 2018-06-10, 2018-06-10],
#       dtype='object', name='Date', length=15068)

# %%
listening_steps_hourly.loc['2018-5-10':'2018-6-10'].fillna(0).groupby(['Hour'])['Song',\
                                                   'Steps'].sum().plot(kind='bar',secondary_y='Song',figsize=(20,8), title='Hourly Steps and Songs listened to')

# %%
wday = {
    0:'Monday',
    1:'Tuesday',
    2:'Wednesday',
    3:'Thursday',
    4:'Friday',
    5:'Saturday',
    6:'Sunday'    
}

# %%
listening_steps_hourly['Day_Of_Week'] = listening_steps_hourly.index.weekday

# %%
#listening_steps_hourly.loc['2017-5-1':'2018-6-10']
listening_steps_hourly.Day_Of_Week = listening_steps_hourly.Day_Of_Week.map(wday)

# %%
listening_steps_hourly.loc['2017-5-1':'2018-6-10'].fillna(0).sort_index().groupby(['Day_Of_Week'])['Song',\
                                                   'Steps'].sum().plot(kind='bar',secondary_y='Song',figsize=(20,8), title='Hourly Steps and Songs listened to')

# %%
listening_steps_hourly.fillna(0).sort_index().groupby(['Day_Of_Week'])['Song',\
                                                   'Steps'].sum().plot(kind='bar',secondary_y='Song',figsize=(20,8), title='Hourly Steps and Songs listened to')

# %%
listening_steps_hourly = pd.get_dummies(listening_steps_hourly, columns=['Steps_Missing','Listening_Missing'],drop_first=True)
#listening_steps_hourly

# %%
listening_steps_hourly.loc['2017-5-1':'2018-6-10'].groupby(['Hour'])['Steps_Missing_True','Listening_Missing_True'].sum().plot(kind='bar',secondary_y='Steps_Missing_True',figsize=(20,8))

# %%
listening_steps_hourly['Date'] = listening_steps_hourly.index.date
listening_steps_hourly['Month'] = listening_steps_hourly.index.month
listening_steps_hourly['Year'] = listening_steps_hourly.index.year

# %%
listening_steps_hourly.loc['2018-5-10':'2018-6-10'][['Song','Steps']].fillna(0).plot(kind='line',secondary_y='Steps',figsize=(20,8))

# %%
sb.pairplot(listening_steps_hourly.loc['2018-5-10':'2018-6-10'].fillna(0),hue='Listening_Missing_True')

# %%
listening.reset_index(inplace=True)

# %%
listening['Listen_Date'] = pd.to_datetime(listening['Listen_Date'])
hourly_step_data['Date'] = pd.to_datetime(hourly_step_data['Date'])

# %%
hourly_step_data.head()

# %%
song_level_listening_steps = hourly_step_data.merge(listening,left_on=['Date','Start_Hour'],right_on = ['Listen_Date','Hour'],how='outer')

# %%
song_level_listening_steps
# Out:
#           Date_x  Start_Hour   Steps                    Date_y  \
# 0     2014-09-10        16.0    10.0                       NaT
# 1     2014-09-10        17.0  1406.0                       NaT
# 2     2014-09-10        18.0   122.0                       NaT
# 3     2014-09-10        19.0    10.0                       NaT
# 4     2014-09-10        20.0    19.0                       NaT
# 5     2014-09-10        22.0    10.0                       NaT
# 6     2014-09-11        10.0     8.0                       NaT
# 7     2014-09-11        11.0    44.0                       NaT
# 8     2014-09-11        12.0    12.0                       NaT
# 9     2014-09-11        13.0    19.0                       NaT
# 10    2014-09-11        14.0    12.0                       NaT
# 11    2014-09-11        15.0   792.0                       NaT
# 12    2014-09-11        16.0    26.0                       NaT
# 13    2014-09-11        17.0   137.0                       NaT
# 14    2014-09-11        18.0   759.0                       NaT
# 15    2014-09-11        19.0  1194.0                       NaT
# 16    2014-09-11        20.0   147.0                       NaT
# 17    2014-09-11        21.0   117.0                       NaT
# 18    2014-09-12        11.0   126.0                       NaT
# 19    2014-09-12        12.0    49.0                       NaT
# 20    2014-09-12        13.0    94.0                       NaT
# 21    2014-09-12        14.0  1321.0                       NaT
# 22    2014-09-12        16.0   753.0                       NaT
# 23    2014-09-12        18.0   103.0                       NaT
# 24    2014-09-12        19.0   272.0                       NaT
# 25    2014-09-12        20.0    70.0                       NaT
# 26    2014-09-12        21.0   152.0                       NaT
# 27    2014-09-12        22.0  1388.0                       NaT
# 28    2014-09-12        23.0  2035.0                       NaT
# 29    2014-09-13         0.0  1583.0                       NaT
# ...          ...         ...     ...                       ...
# 19922        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19923        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19924        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19925        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19926        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19927        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19928        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19929        NaT         NaN     NaN 2016-06-09 17:00:00-07:00
# 19930        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19931        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19932        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19933        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19934        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19935        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19936        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19937        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19938        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19939        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19940        NaT         NaN     NaN 2016-06-09 16:00:00-07:00
# 19941        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19942        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19943        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19944        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19945        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19946        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19947        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19948        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19949        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19950        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
# 19951        NaT         NaN     NaN 2016-06-09 15:00:00-07:00
#
#            Artist_Name                                   Album  \
# 0                  NaN                                     NaN
# 1                  NaN                                     NaN
# 2                  NaN                                     NaN
# 3                  NaN                                     NaN
# 4                  NaN                                     NaN
# 5                  NaN                                     NaN
# 6                  NaN                                     NaN
# 7                  NaN                                     NaN
# 8                  NaN                                     NaN
# 9                  NaN                                     NaN
# 10                 NaN                                     NaN
# 11                 NaN                                     NaN
# 12                 NaN                                     NaN
# 13                 NaN                                     NaN
# 14                 NaN                                     NaN
# 15                 NaN                                     NaN
# 16                 NaN                                     NaN
# 17                 NaN                                     NaN
# 18                 NaN                                     NaN
# 19                 NaN                                     NaN
# 20                 NaN                                     NaN
# 21                 NaN                                     NaN
# 22                 NaN                                     NaN
# 23                 NaN                                     NaN
# 24                 NaN                                     NaN
# 25                 NaN                                     NaN
# 26                 NaN                                     NaN
# 27                 NaN                                     NaN
# 28                 NaN                                     NaN
# 29                 NaN                                     NaN
# ...                ...                                     ...
# 19922     Modest Mouse  Good News For People Who Love Bad News
# 19923          Lettuce                                    Rage
# 19924      Neon Indian                 VEGA INTL. NIGHT SCHOOL
# 19925       Disclosure                         Settle (Deluxe)
# 19926  Trails and Ways                               Pathology
# 19927       Peking Duk                     High (The Remix EP)
# 19928       The Police                        Message In A Box
# 19929         Poolside                   Pacific Standard Time
# 19930    One Direction       Made In the A.M. (Deluxe Edition)
# 19931       Peking Duk                       Songs to Sweat to
# 19932       Kanye West                                  Clique
# 19933       Disclosure                        Caracal (Deluxe)
# 19934    Glass Animals                           ZABA (Deluxe)
# 19935        Santigold   Who Be Lovin Me (feat. ILOVEMAKONNEN)
# 19936      Gravediggaz                             6 Feet Deep
# 19937             Baio                               The Names
# 19938        The Shins                  Wincing the Night Away
# 19939        Fetty Wap                              Jimmy Choo
# 19940            EVE 6                                   Eve 6
# 19941          Mac Dre              The Best of Mac Dre Vol. 5
# 19942       Kanye West                       The Life Of Pablo
# 19943        Sam Smith               Lay Me Down (Flume Remix)
# 19944        Meek Mill      B Boy (feat. Big Sean & A$AP Ferg)
# 19945       Kanye West                       The Life Of Pablo
# 19946         sjowgren                               Seventeen
# 19947        Izzy Bizu                    Adam & Eve (Remixes)
# 19948       A$AP Rocky                       At.Long.Last.A$AP
# 19949              Omi                             Cheerleader
# 19950    Glass Animals                           ZABA (Deluxe)
# 19951        Blackbear                               deadroses
#
#                                              Song  Hour Listen_Date
# 0                                             NaN   NaN         NaT
# 1                                             NaN   NaN         NaT
# 2                                             NaN   NaN         NaT
# 3                                             NaN   NaN         NaT
# 4                                             NaN   NaN         NaT
# 5                                             NaN   NaN         NaT
# 6                                             NaN   NaN         NaT
# 7                                             NaN   NaN         NaT
# 8                                             NaN   NaN         NaT
# 9                                             NaN   NaN         NaT
# 10                                            NaN   NaN         NaT
# 11                                            NaN   NaN         NaT
# 12                                            NaN   NaN         NaT
# 13                                            NaN   NaN         NaT
# 14                                            NaN   NaN         NaT
# 15                                            NaN   NaN         NaT
# 16                                            NaN   NaN         NaT
# 17                                            NaN   NaN         NaT
# 18                                            NaN   NaN         NaT
# 19                                            NaN   NaN         NaT
# 20                                            NaN   NaN         NaT
# 21                                            NaN   NaN         NaT
# 22                                            NaN   NaN         NaT
# 23                                            NaN   NaN         NaT
# 24                                            NaN   NaN         NaT
# 25                                            NaN   NaN         NaT
# 26                                            NaN   NaN         NaT
# 27                                            NaN   NaN         NaT
# 28                                            NaN   NaN         NaT
# 29                                            NaN   NaN         NaT
# ...                                           ...   ...         ...
# 19922                                    Float On  17.0  2016-06-09
# 19923                                  Move on Up  17.0  2016-06-09
# 19924                                       Annie  17.0  2016-06-09
# 19925                  When a Fire Starts to Burn  17.0  2016-06-09
# 19926                                   Skeletons  17.0  2016-06-09
# 19927                        High - Yahtzel Remix  17.0  2016-06-09
# 19928                                     Roxanne  17.0  2016-06-09
# 19929                                Harvest Moon  17.0  2016-06-09
# 19930                               Temporary Fix  16.0  2016-06-09
# 19931                                        High  16.0  2016-06-09
# 19932                                      Clique  16.0  2016-06-09
# 19933                                   Nocturnal  16.0  2016-06-09
# 19934                     Cocoa Hooves - Stripped  16.0  2016-06-09
# 19935       Who Be Lovin Me (feat. ILoveMakonnen)  16.0  2016-06-09
# 19936                               1-800 Suicide  16.0  2016-06-09
# 19937                             Sister of Pearl  16.0  2016-06-09
# 19938                            Sleeping Lessons  16.0  2016-06-09
# 19939                                  Jimmy Choo  16.0  2016-06-09
# 19940                                  Inside Out  16.0  2016-06-09
# 19941                              Off Da Richter  15.0  2016-06-09
# 19942                                        Fade  15.0  2016-06-09
# 19943                   Lay Me Down - Flume Remix  15.0  2016-06-09
# 19944          B Boy (feat. Big Sean & A$AP Ferg)  15.0  2016-06-09
# 19945                                    Feedback  15.0  2016-06-09
# 19946                                   seventeen  15.0  2016-06-09
# 19947                  Adam & Eve - Swindle Remix  15.0  2016-06-09
# 19948                                    Everyday  15.0  2016-06-09
# 19949  Cheerleader - Felix Jaehn Remix Radio Edit  15.0  2016-06-09
# 19950                                       Hazey  15.0  2016-06-09
# 19951                                       90210  15.0  2016-06-09
#
# [19952 rows x 9 columns]

# %%
song_level_listening_steps['Date'] = song_level_listening_steps.Date.fillna(song_level_listening_steps.Listen_Date)
song_level_listening_steps['Hour'] = song_level_listening_steps.Hour.fillna(song_level_listening_steps.Start_Hour)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-180-532212662c97> in <module>()
# ----> 1 song_level_listening_steps['Date'] = song_level_listening_steps.Date.fillna(song_level_listening_steps.Listen_Date)
#       2 song_level_listening_steps['Hour'] = song_level_listening_steps.Hour.fillna(song_level_listening_steps.Start_Hour)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'Date'

# %%
song_level_listening_steps.drop(['startDate'],axis=1,inplace=True)
song_level_listening_steps.set_index('Date',inplace=True)

# %%
song_level_listening_steps.sort_index(inplace=True)

# %%
recent_listening = song_level_listening_steps.loc['2018-5-10':'2018-6-10']

# %%
recent_listening['Above_Avg_Steps'] = np.where(recent_listening['Steps']/recent_listening['Steps'].mean() >=1,1,0)

# %%
recent_listening[['Above_Avg_Steps','Artist_Name']].drop_duplicates().groupby('Above_Avg_Steps').count()

# %%
#pd.DataFrame(recent_listening.fillna(0).groupby(by=[recent_listening.index,'Song'])['Steps'].count()).merge(recent_listening)
recent_listening = pd.DataFrame(recent_listening.fillna(0).groupby(by=[recent_listening.index,
                                                    'Song'])['Steps'].count()).rename({'Steps':'Listens_Per_Hour'},axis=1).reset_index().merge(recent_listening.reset_index(),
                                                                                                                          left_on=['Date','Song'],right_on=['Date','Song'])

# %%
recent_listening.set_index('Date',inplace=True)

# %%
recent_listening.Listens_Per_Hour.value_counts(normalize=True)

# %%
#pd.DataFrame(recent_listening.fillna(0).groupby(by=[recent_listening.index,'Song'])['Steps'].count()).merge(recent_listening)
recent_listening = pd.DataFrame(recent_listening.fillna(0).groupby(by=[recent_listening.index])['Artist_Name'].nunique()).rename({'Artist_Name':'Artists_Per_Hour'},axis=1).reset_index().merge(recent_listening.reset_index(),
                                                                                                                          left_on=['Date'],right_on=['Date'])

# %%
recent_listening.Artists_Per_Hour.value_counts(normalize=True)

# %%
recent_listening.set_index('Date',inplace=True)

# %%
recent_listening['Hour'] = recent_listening.index.hour

# %%
recent_listening[['Steps','Listens_Per_Hour','Hour']].groupby(['Hour']).mean().plot(kind='line',secondary_y='Listens_Per_Hour',figsize=(20,8))
